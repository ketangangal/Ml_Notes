# %% [markdown]
# # Pandas Series

# %%
import numpy as np
import pandas as pd

# %%
mydata = [1192,54795,55]
myindex = ['India','Usa','Uk']

# %%
a = pd.Series(data = mydata , index=myindex)

# %%
print(a)
# Out:
# India     1192
# Usa      54795
# Uk          55
# dtype: int64

# %%
a[0]
# Out:
# 1192

# %%
a['India']
# Out:
# 1192

# %%
mydict = {'fname': 'Joe', 'lname': 'Fonebone', 'age': 51, 'spouse': 'Edna',
'children': ['Ralph', 'Betty', 'Joey'], 'pets': {'dog': 'Fido', 'cat': 'Sox'}}

# %%
a = pd.Series(mydict)

# %%
a
# Out:
# fname                                 Joe
# lname                            Fonebone
# age                                    51
# spouse                               Edna
# children             [Ralph, Betty, Joey]
# pets        {'dog': 'Fido', 'cat': 'Sox'}
# dtype: object

# %%
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100, 'India': 210,'USA': 260,'China': 500}

# %%
sales_q1 = pd.Series(q1)

# %%
sales_q2 = pd.Series(q2)

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q2
# Out:
# Brazil    100
# India     210
# USA       260
# China     500
# dtype: int64

# %%
sales_q1['India']
# Out:
# 200

# %%
sales_q1[2]
# Out:
# 200

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
sales_q1['Japan']
# Out:
# 80

# %%
sales_q1 *100
# Out:
# Japan     8000
# China    45000
# India    20000
# USA      25000
# dtype: int64

# %%
sales_q1/1000
# Out:
# Japan    0.08
# China    0.45
# India    0.20
# USA      0.25
# dtype: float64

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    200
# USA      250
# dtype: int64

# %%
sales_q1 + sales_q2
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
sales_q1.add(sales_q2,fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
sales_q1.div(sales_q2,fill_value=0)
# Out:
# Brazil    0.000000
# China     0.900000
# India     0.952381
# Japan          inf
# USA       0.961538
# dtype: float64

# %%
myindex = ['USA','CA','IND','RUS']

# %%
mycolums = ['Jobs','Food','Sex','violence']

# %%
mydata = np.random.randint(1,1000,(4,4))

# %%
mat= pd.DataFrame(mydata,index=myindex,columns=mycolums)

# %%
mat
# Out:
#      Jobs  Food  Sex  violence
# USA   670   792  360        13
# CA    859   947  203       557
# IND   918   701  631       436
# RUS   812   663  317       180

# %%
mat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, USA to RUS
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Jobs      4 non-null      int32
#  1   Food      4 non-null      int32
#  2   Sex       4 non-null      int32
#  3   violence  4 non-null      int32
# dtypes: int32(4)
# memory usage: 96.0+ bytes

# %%
mat.keys()
# Out:
# Index(['Jobs', 'Food', 'Sex', 'violence'], dtype='object')

# %%
pwd
# Out:
# 'C:\\Users\\Ketan Gangal\\OneDrive\\Desktop\\python_basic\\Untitled Folder'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B6EA-4595
#
#  Directory of C:\Users\Ketan Gangal\OneDrive\Desktop\python_basic\Untitled Folder
#
# 14-12-2020  04.25 PM    <DIR>          .
# 14-12-2020  04.25 PM    <DIR>          ..
# 10-12-2020  03.06 PM    <DIR>          .ipynb_checkpoints
# 11-12-2020  08.19 PM    <DIR>          machine_learning
# 10-12-2020  03.03 PM            32,278 numpy_basics.ipynb
# 14-12-2020  04.25 PM            11,973 Pandas_practice.ipynb
# 30-08-2018  11.54 AM    <DIR>          Refactored_Py_DS_ML_Bootcamp-master
#                2 File(s)         44,251 bytes
#                5 Dir(s)  1,019,562,897,408 bytes free

# %%
df = pd.read_csv('C:\\Users\\Ketan Gangal\\OneDrive\\Desktop\\python_basic\\Untitled Folder\\machine_learning\\DATA\\tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# # columns

# %%
h = df.head()

# %%
h
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             8.495
# 1       10.34  1.66    Male     No  Sun  Dinner     3             3.447
# 2       21.01  3.50    Male     No  Sun  Dinner     3             7.003
# 3       23.68  3.31    Male     No  Sun  Dinner     2            11.840
# 4       24.59  3.61  Female     No  Sun  Dinner     4             6.148
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
h['total_bill']
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# Name: total_bill, dtype: float64

# %%
h[['total_bill','tip']]
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
h['total_bill'] + h['tip']
# Out:
# 0    18.00
# 1    12.00
# 2    24.51
# 3    26.99
# 4    28.20
# dtype: float64

# %%
df['Total_Money'] = df['total_bill'] + df['tip']

# %%
df['Total_Money'] = df['total_bill'] - df['tip']

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  Total_Money
# ...

# %%
df['price_per_person'] = np.round(df['total_bill']/df['size'],3)

# %%
df = df.drop(columns= 'Total_Money')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2             8.495
# 1         10.34  1.66    Male     No   Sun  Dinner     3             3.447
# 2         21.01  3.50    Male     No   Sun  Dinner     3             7.003
# 3         23.68  3.31    Male     No   Sun  Dinner     2            11.840
# 4         24.59  3.61  Female     No   Sun  Dinner     4             6.148
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3             9.677
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2            13.590
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2            11.335
# 242       17.82  1.75    Male     No   Sat  Dinner     2             8.910
# 243       18.78  3.00  Female     No  Thur  Dinner     2             9.390
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# # rows

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2             8.495
# 1       10.34  1.66    Male     No  Sun  Dinner     3             3.447
# 2       21.01  3.50    Male     No  Sun  Dinner     3             7.003
# 3       23.68  3.31    Male     No  Sun  Dinner     2            11.840
# 4       24.59  3.61  Female     No  Sun  Dinner     4             6.148
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
# make index/ rows name from cloumns

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.set_index('Payment ID')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                8.495  Christy Cunningham  3560325168603410
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2             8.495
# 1         10.34  1.66    Male     No   Sun  Dinner     3             3.447
# 2         21.01  3.50    Male     No   Sun  Dinner     3             7.003
# 3         23.68  3.31    Male     No   Sun  Dinner     2            11.840
# 4         24.59  3.61  Female     No   Sun  Dinner     4             6.148
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3             9.677
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2            13.590
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2            11.335
# 242       17.82  1.75    Male     No   Sat  Dinner     2             8.910
# 243       18.78  3.00  Female     No  Thur  Dinner     2             9.390
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df = df.set_index('Payment ID')

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                8.495  Christy Cunningham  3560325168603410
# ...

# %%
df.reset_index()
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0               8.495  Christy Cunningham  3560325168603410
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 0      Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number
# 0               8.495  Christy Cunningham  3560325168603410
# ...

# %%
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                8.495  Christy Cunningham  3560325168603410
# Sun4608                3.447      Douglas Tucker  4478071379779230
# Sun4458                7.003      Travis Walters  6011812112971322
# Sun5260               11.840    Nathaniel Harris  4676137647685994
# Sun2251                6.148        Tonya Carter  4832732618637221

# %%
df.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                 8.495
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                 8.495
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
# Grab multiple rows use slice

# %%
df.iloc[0:4]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                8.495  Christy Cunningham  3560325168603410
# Sun4608                3.447      Douglas Tucker  4478071379779230
# Sun4458                7.003      Travis Walters  6011812112971322
# Sun5260               11.840    Nathaniel Harris  4676137647685994

# %%
df.loc[['Sun2959','Sun5260']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                8.495  Christy Cunningham  3560325168603410
# Sun5260               11.840    Nathaniel Harris  4676137647685994

# %%
#remove and insert rows

# %%
df.drop('Sun2959',axis=0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                3.447    Douglas Tucker  4478071379779230
# ...

# %%
df.append(df.iloc[0],True)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2             8.495
# 1         10.34  1.66    Male     No   Sun  Dinner     3             3.447
# 2         21.01  3.50    Male     No   Sun  Dinner     3             7.003
# 3         23.68  3.31    Male     No   Sun  Dinner     2            11.840
# 4         24.59  3.61  Female     No   Sun  Dinner     4             6.148
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 242       17.82  1.75    Male     No   Sat  Dinner     2             8.910
# 243       18.78  3.00  Female     No  Thur  Dinner     2             9.390
# 244       16.99  1.01  Female     No   Sun  Dinner     2             8.495
# 245       16.99  1.01  Female     No   Sun  Dinner     2             8.495
# 246       16.99  1.01  Female     No   Sun  Dinner     2             8.495
#
#              Payer Name         CC Number
# ...

# %%
# if you want to append then dimension should be same  in ml you wont do duplicate unique is requied
df.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                 8.495
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.drop('Sun2959')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                3.447    Douglas Tucker  4478071379779230
# ...

# %%
df.append(created_row).tail(11)
# Out:
#                    0  CC Number Payer Name  day  price_per_person  sex  size  \
# 0               hell        NaN        NaN  NaN               NaN  NaN   NaN
# 1              16.99        NaN        NaN  NaN               NaN  NaN   NaN
# 2               1.01        NaN        NaN  NaN               NaN  NaN   NaN
# 3             Female        NaN        NaN  NaN               NaN  NaN   NaN
# 4                 No        NaN        NaN  NaN               NaN  NaN   NaN
# 5                Sun        NaN        NaN  NaN               NaN  NaN   NaN
# 6             Dinner        NaN        NaN  NaN               NaN  NaN   NaN
# 7             28.495        NaN        NaN  NaN               NaN  NaN   NaN
# 8            Christy        NaN        NaN  NaN               NaN  NaN   NaN
# 9         Cunningham        NaN        NaN  NaN               NaN  NaN   NaN
# 10  3560325168603410        NaN        NaN  NaN               NaN  NaN   NaN
#
#    smoker time  tip  total_bill
# ...
