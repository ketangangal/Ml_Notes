# %% [markdown]
# # groupby

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Ketan Gangal\\OneDrive\\Desktop\\python_basic\\Ml\\00 ml_course\\DATA\\mpg.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.groupby('model_year').mean().head()
# Out:
#                   mpg  cylinders  displacement       weight  acceleration  \
# model_year
# 70          17.689655   6.758621    281.413793  3372.793103     12.948276
# 71          21.250000   5.571429    209.750000  2995.428571     15.142857
# 72          18.714286   5.821429    218.375000  3237.714286     15.125000
# 73          17.100000   6.375000    256.875000  3419.025000     14.312500
# 74          22.703704   5.259259    171.740741  2877.925926     16.203704
#
#               origin
# model_year
# 70          1.310345
# 71          1.428571
# 72          1.535714
# 73          1.375000
# 74          1.666667

# %%
a = df.groupby(['model_year','cylinders']).mean()
a.head()
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#
#                         origin
# model_year cylinders
# 70         4          2.285714
#            6          1.000000
#            8          1.000000
# 71         4          1.923077
#            6          1.000000

# %%
a.index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
a.iloc[1]
# Out:
# mpg               20.5
# displacement     199.0
# weight          2710.5
# acceleration      15.5
# origin             1.0
# Name: (70, 6), dtype: float64

# %%
a.loc[(70,4)]
# Out:
# mpg               25.285714
# displacement     107.000000
# weight          2292.571429
# acceleration      16.000000
# origin             2.285714
# Name: (70, 4), dtype: float64

# %%
a.index.names
# Out:
# FrozenList(['model_year', 'cylinders'])

# %%
a.loc[70]
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %%
# grabing based on cross section .xs

# %%
a.xs(key=4,axis=0,level ='cylinders')
# Out:
#                   mpg  displacement       weight  acceleration    origin
# model_year
# 70          25.285714    107.000000  2292.571429     16.000000  2.285714
# 71          27.461538    101.846154  2056.384615     16.961538  1.923077
# 72          23.428571    111.535714  2382.642857     17.214286  1.928571
# 73          22.727273    109.272727  2338.090909     17.136364  2.000000
# 74          27.800000     96.533333  2151.466667     16.400000  2.200000
# 75          25.250000    114.833333  2489.250000     15.833333  2.166667
# 76          26.766667    106.333333  2306.600000     16.866667  1.866667
# 77          29.107143    106.500000  2205.071429     16.064286  1.857143
# 78          29.576471    112.117647  2296.764706     16.282353  2.117647
# 79          31.525000    113.583333  2357.583333     15.991667  1.583333
# 80          34.612000    111.000000  2360.080000     17.144000  2.200000
# 81          32.814286    108.857143  2275.476190     16.466667  2.095238
# ...

# %%
a.swaplevel()
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 4         70          25.285714    107.000000  2292.571429     16.000000
# 6         70          20.500000    199.000000  2710.500000     15.500000
# 8         70          14.111111    367.555556  3940.055556     11.194444
# 4         71          27.461538    101.846154  2056.384615     16.961538
# 6         71          18.000000    243.375000  3171.875000     14.750000
# 8         71          13.428571    371.714286  4537.714286     12.214286
# 3         72          19.000000     70.000000  2330.000000     13.500000
# 4         72          23.428571    111.535714  2382.642857     17.214286
# 8         72          13.615385    344.846154  4228.384615     13.000000
# 3         73          18.000000     70.000000  2124.000000     13.500000
# 4         73          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
a.sort_index(level ='model_year',ascending=False)
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 82         6          28.333333    225.000000  2931.666667     16.033333
#            4          32.071429    118.571429  2402.321429     16.703571
# 81         8          26.600000    350.000000  3725.000000     19.000000
#            6          23.428571    184.000000  3093.571429     15.442857
#            4          32.814286    108.857143  2275.476190     16.466667
# 80         6          25.900000    196.500000  3145.500000     15.050000
#            5          36.400000    121.000000  2950.000000     19.900000
#            4          34.612000    111.000000  2360.080000     17.144000
#            3          23.700000     70.000000  2420.000000     12.500000
# 79         8          18.630000    321.400000  3862.900000     15.400000
#            6          22.950000    205.666667  3025.833333     15.433333
# ...

# %%
df.agg(['sum','mean'])
# Out:
#               mpg    cylinders  displacement  \
# sum   9358.800000  2171.000000  76983.500000
# mean    23.514573     5.454774    193.425879
#
#                                              horsepower        weight  \
# sum   1301651501501401982202152251901701601502259595...  1.182229e+06
# mean                                                NaN  2.970425e+03
#
#       acceleration   model_year      origin  \
# sum     6196.10000  30252.00000  626.000000
# mean      15.56809     76.01005    1.572864
#
#                                                    name
# sum   chevrolet chevelle malibubuick skylark 320plym...
# mean                                                NaN

# %%
df.agg(['sum','mean'])[['mpg','displacement']]
# Out:
#               mpg  displacement
# sum   9358.800000  76983.500000
# mean    23.514573    193.425879

# %%
df.agg({'mpg':['sum','std'],'cylinders':['mean','sum']})
# Out:
#               mpg    cylinders
# mean          NaN     5.454774
# std      7.815984          NaN
# sum   9358.800000  2171.000000

# %%
df.groupby(['model_year','cylinders']).agg({'mpg':['sum','std'],'weight':['mean','sum']})
# Out:
#                         mpg                 weight
#                         sum       std         mean    sum
# model_year cylinders
# 70         4          177.0  1.112697  2292.571429  16048
#            6           82.0  1.732051  2710.500000  10842
#            8          254.0  2.609685  3940.055556  70921
# 71         4          357.0  3.502746  2056.384615  26733
#            6          144.0  1.069045  3171.875000  25375
#            8           94.0  0.786796  4537.714286  31764
# 72         3           19.0       NaN  2330.000000   2330
#            4          328.0  3.056249  2382.642857  33357
#            8          177.0  1.502135  4228.384615  54969
# 73         3           18.0       NaN  2124.000000   2124
#            4          250.0  3.319365  2338.090909  25719
#            6          152.0  2.203893  2917.125000  23337
#            8          264.0  1.361114  4279.050000  85581
# 74         4          417.0  2.932576  2151.466667  32272
# ...

# %% [markdown]
# # merge and concat

# %%
one = {'A':['A0','A1','A2','A3'],'B':['B0','B1','B2','B3']}
one =  pd.DataFrame(one)

# %%
two = {'C':['C0','C1','C2','C3'],'D':['D0','D1','D2','D3']}
two = pd.DataFrame(two)

# %%
pd.concat([one,two],axis=1) # feature adding
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
pd.concat([one,two],axis=0) # data point adding
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
two.columns = one.columns

# %%
d = pd.concat([one,two],axis=0)
d.index = range(len(d))

# %%
d
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3
# 4  C0  D0
# 5  C1  D1
# 6  C2  D2
# 7  C3  D3

# %%
######################## merge ############################
'''
1. inner 
2. outer merge
3. left or right merge
'''
# Out:
# '\n1. inner \n2. outer merge\n3. left or right merge\n'

# %%
'''pd.merge(
    left,
    right,
    how = 'inner',
    on=None,
    left_on=None,
    right_on=None,
    left_index: bool = False,
    right_index: bool = False)'''
# Out:
# "pd.merge(\n    left,\n    right,\n    how = 'inner',\n    on=None,\n    left_on=None,\n    right_on=None,\n    left_index: bool = False,\n    right_index: bool = False)"

# %%
registrations = pd.DataFrame({'reg_id':[1,2,3,4],'name':['Andrew','Bobo','Claire','David']})
logins = pd.DataFrame({'log_id':[1,2,3,4],'name':['Xavier','Andrew','Yolanda','Bobo']})

# %%
registrations
# Out:
#    reg_id    name
# 0       1  Andrew
# 1       2    Bobo
# 2       3  Claire
# 3       4   David

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
pd.merge(registrations,logins,how='inner',on ='name' )
# Out:
#    reg_id    name  log_id
# 0       1  Andrew       2
# 1       2    Bobo       4

# %%
pd.merge(registrations,logins,how = 'outer',on = 'name')
# Out:
#    reg_id     name  log_id
# 0     1.0   Andrew     2.0
# 1     2.0     Bobo     4.0
# 2     3.0   Claire     NaN
# 3     4.0    David     NaN
# 4     NaN   Xavier     1.0
# 5     NaN  Yolanda     3.0

# %%
pd.merge(registrations,logins,how = 'left',on = 'name')
# Out:
#    reg_id    name  log_id
# 0       1  Andrew     2.0
# 1       2    Bobo     4.0
# 2       3  Claire     NaN
# 3       4   David     NaN

# %%
pd.merge(registrations,logins,how = 'right',on = 'name')
# Out:
#    reg_id     name  log_id
# 0     NaN   Xavier       1
# 1     1.0   Andrew       2
# 2     NaN  Yolanda       3
# 3     2.0     Bobo       4

# %%
################### left on Right on left index right index

# %%
registrations = registrations.set_index('name')

# %%
registrations
# Out:
#         reg_id
# name
# Andrew       1
# Bobo         2
# Claire       3
# David        4

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
pd.merge(registrations,logins,how='inner',left_index=True,right_on='name')
# Out:
#    reg_id  log_id    name
# 1       1       2  Andrew
# 3       2       4    Bobo

# %%
pd.merge(logins,registrations,right_index=True,left_on='name')
# Out:
#    log_id    name  reg_id
# 1       2  Andrew       1
# 3       4    Bobo       2

# %%
registrations = registrations.reset_index()

# %%
registrations.columns = ['reg_name','reg_id']

# %%
registrations
# Out:
#   reg_name  reg_id
# 0   Andrew       1
# 1     Bobo       2
# 2   Claire       3
# 3    David       4

# %%
logins
# Out:
#    log_id     name
# 0       1   Xavier
# 1       2   Andrew
# 2       3  Yolanda
# 3       4     Bobo

# %%
pd.merge(registrations,logins,how ='inner',left_on='reg_name',right_on ='name')
# Out:
#   reg_name  reg_id  log_id    name
# 0   Andrew       1       2  Andrew
# 1     Bobo       2       4    Bobo

# %%
registrations.columns = ['name','id']

# %%
logins.columns = ['id','name']

# %%
pd.merge(registrations,logins,on='name')
# Out:
#      name  id_x  id_y
# 0  Andrew     1     2
# 1    Bobo     2     4

# %%
pd.merge(registrations,logins,on='name',suffixes=('_reg','_log'))
# Out:
#      name  id_reg  id_log
# 0  Andrew       1       2
# 1    Bobo       2       4

# %% [markdown]
# # text mtds

# %%
names = pd.Series(['andrew','bobo','claire','david','4'])

# %%
names.str.capitalize()
# Out:
# 0    Andrew
# 1      Bobo
# 2    Claire
# 3     David
# 4         4
# dtype: object

# %%
names.str.lower()
# Out:
# 0    andrew
# 1      bobo
# 2    claire
# 3     david
# 4         4
# dtype: object

# %%
tech_finance = ['GOOG,APPL,AMZN','JPM,BAC,GS']

# %%
tickers = pd.Series(tech_finance)

# %%
tickers
# Out:
# 0    GOOG,APPL,AMZN
# 1        JPM,BAC,GS
# dtype: object

# %%
tickers.str.split(',').str[0]
# Out:
# 0    GOOG
# 1     JPM
# dtype: object

# %%
tickers.str.split(',',expand = True)
# Out:
#       0     1     2
# 0  GOOG  APPL  AMZN
# 1   JPM   BAC    GS

# %%
messy_names = pd.Series(["andrew  ","bo;bo","  claire  "])

# %%
messy_names
# Out:
# 0      andrew
# 1         bo;bo
# 2      claire
# dtype: object

# %%
messy_names.str.replace(";","").str.strip().str.capitalize()
# Out:
# 0    Andrew
# 1      Bobo
# 2    Claire
# dtype: object
