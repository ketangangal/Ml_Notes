# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Ketan Gangal\\OneDrive\\Desktop\\python_basic\\Ml\\00 ml_course\\05-Seaborn\\dm_office_sales.csv")

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.scatterplot(x='salary',y='sales',data = df) # because it is made on mpl we can use mpl mts calls
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.scatterplot(x='salary',y='sales',data = df,hue='salary') # use gradient color ( light to dark)

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.scatterplot(x='salary',y='sales',data = df,hue = 'level of education',palette='Dark2')

# %%
plt.figure(figsize=(10,5),dpi = 200)
sns.scatterplot(x = 'salary',y="sales",data = df,size = 'level of education',hue = 'level of education')

# %%
plt.figure(figsize=(10,5),dpi = 200)
sns.scatterplot(x = 'salary',y="sales",data = df,s= 100 ,hue = 'level of education')

# %%
plt.figure(figsize=(10,5),dpi = 200)
sns.scatterplot(x = 'salary',y="sales",data = df,size= 'work experience' ,hue = 'level of education')

# %%
plt.figure(figsize=(10,5),dpi = 200)
sns.scatterplot(x = 'salary',y="sales",data = df,
                style = 'level of education',
                hue = 'level of education',alpha =0) # all invisiable

# %%
plt.figure(figsize=(10,5),dpi = 200)
sns.scatterplot(x = 'salary',y="sales",data = df,
                style = 'level of education',
                hue = 'level of education',alpha =1) # all visiable

# %%
plt.figure(figsize=(10,5),dpi = 200)
sns.scatterplot(x = 'salary',y="sales",data = df,
                style = 'level of education',
                hue = 'level of education',alpha =0.5) # in between

# %% [markdown]
# # Histogram , KDE , RUG

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
# y axis has no meaning
plt.figure(figsize=(10,4),dpi = 200)
sns.rugplot(x= 'salary',data = df,hue= 'level of education',height = 0.5)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
# sns.displot() , sns.histplot()
sns.set(style = 'darkgrid')
sns.displot(data = df, x = 'salary' ,bins = 10) # blocks of size 10

# %%
sns.set(style = 'ticks') # high level cmd ( need to reset kernel)
sns.displot(data = df, x = 'salary' ,bins = 10) # blocks of size 10

# %%
sns.histplot(data = df,x = 'salary',bins = 10,kde =True) # it doesn't have Rug
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
sns.displot(data = df, x = 'salary' ,kde = True,rug = True) # blocks of size 10

# %%
sns.kdeplot(data = df,x = 'salary')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
sample = np.random.randint(0,100,200)

# %%
df = pd.DataFrame(data = sample , columns = ['age'])

# %%
df.head()
# Out:
#    age
# 0   26
# 1    3
# 2   99
# 3    5
# 4   68

# %%
sns.rugplot(data = df,x = 'age',height = 0.5)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.displot(data = df,x= 'age',kde = True,rug=True ,color = 'green')

# %%
plt.figure(figsize=(10,2),dpi = 200)
sns.kdeplot(data = df , x = 'age',clip=[0,100],bw_adjust = 0.5,shade = True) 
# bigger the band width more is the normalization and sometime which is not required
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
#df.groupby(df['level of education']).count()
df['division'].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %%
sns.set(style = 'darkgrid')
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(data=df,x='division')
# Out:
# <AxesSubplot:xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(data=df,x='level of education',hue='division',palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize = (10,4),dpi=200)
sns.barplot(data = df,x = 'level of education', y = 'salary',estimator = np.mean,ci = 'sd',
           hue = 'division')
plt.legend(loc=(1.05,1))
